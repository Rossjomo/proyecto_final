# %%
import pandas as pd

# Load all model metrics
knn = pd.read_csv("knn.csv")
knn_ov = pd.read_csv("knn_ov.csv")
knn_ov_sa = pd.read_csv("knn_ov_saga.csv")
knn_un = pd.read_csv("knn_un.csv")
knn_un_sa = pd.read_csv("knn_un_saga.csv")
knn_com = pd.read_csv("knn_combined.csv")
knn_com_sag = pd.read_csv("knn_combined_saga.csv")
knn_thresh = pd.read_csv("knn_threshold.csv")

# Combine all into a single DataFrame
all_models_df = pd.concat([knn, knn_ov, knn_ov_sa, knn_un, knn_un_sa, knn_com, knn_com_sag, knn_thresh], ignore_index=True)

# Save the final dataset
#all_models_df.to_csv("all_models_metrics.csv", index=False)

all_models_df
# Out:
#   Model  Accuracy  Precision  Sensitivity (Recall)  Specificity  \
# 0   KNN  0.928136   0.913194              0.928136     0.987213
# 1   KNN  0.888416   0.889211              0.888416     0.910857
# 2   KNN  0.895755   0.896506              0.895755     0.917368
# 3   KNN  0.793654   0.793653              0.793654     0.795654
# 4   KNN  0.748846   0.749480              0.748846     0.728174
# 5   KNN  0.889707   0.890493              0.889707     0.911862
# 6   KNN  0.886153   0.886993              0.886153     0.909166
# 7   KNN  0.898565   0.899572              0.898565     0.923538
#
#    Negative Predictive Value (NPV)  F1 Score
# 0                         0.937932  0.913509
# 1                         0.871551  0.888362
# 2                         0.879186  0.895708
# 3                         0.795351  0.793653
# 4                         0.763084  0.748764
# 5                         0.872854  0.889657
# 6                         0.868836  0.886097
# ...
